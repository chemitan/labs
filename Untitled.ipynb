# %%
# Import the required libraries
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Import the file
df = pd.read_csv('turnstile_180901.txt')

#  number of rows ans columns in df
print(df.shape)

#  first five rows of df
df.head()
# Out:
# (197625, 11)
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    EXITS
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %%
#changing rows to lowercase
# Rename all the columns to lower case
df.columns = [col.lower() for col in df.columns]
df.columns
# Out:
# Index(['c/a', 'unit', 'scp', 'station', 'linename', 'division', 'date', 'time',
#        'desc', 'entries',
#        'exits                                                               '],
#       dtype='object')

# %%
# Change the index to 'linename'
df = df.set_index('linename')

df.head()
# Out:
#            c/a  unit       scp station division        date      time  \
# linename
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  00:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  04:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  08:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  12:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  16:00:00
#
#              desc  entries  \
# linename
# NQR456W   REGULAR  6736067
# NQR456W   REGULAR  6736087
# NQR456W   REGULAR  6736105
# NQR456W   REGULAR  6736180
# NQR456W   REGULAR  6736349
#
#           exits
# linename
# NQR456W                                             2283184
# NQR456W                                             2283188
# NQR456W                                             2283229
# NQR456W                                             2283314
# NQR456W                                             2283384

# %%
df = df.set_index('unit')
df.head()
# Out:
#        c/a       scp station division        date      time     desc  entries  \
# unit
# R051  A002  02-00-00   59 ST      BMT  08/25/2018  00:00:00  REGULAR  6736067
# R051  A002  02-00-00   59 ST      BMT  08/25/2018  04:00:00  REGULAR  6736087
# R051  A002  02-00-00   59 ST      BMT  08/25/2018  08:00:00  REGULAR  6736105
# R051  A002  02-00-00   59 ST      BMT  08/25/2018  12:00:00  REGULAR  6736180
# R051  A002  02-00-00   59 ST      BMT  08/25/2018  16:00:00  REGULAR  6736349
#
#       exits
# unit
# R051                                            2283184
# R051                                            2283188
# R051                                            2283229
# R051                                            2283314
# R051                                            2283384

# %%
df.reset_index()
# Out:
#         unit    c/a       scp        station division        date      time  \
# 0       R051   A002  02-00-00          59 ST      BMT  08/25/2018  00:00:00
# 1       R051   A002  02-00-00          59 ST      BMT  08/25/2018  04:00:00
# 2       R051   A002  02-00-00          59 ST      BMT  08/25/2018  08:00:00
# 3       R051   A002  02-00-00          59 ST      BMT  08/25/2018  12:00:00
# 4       R051   A002  02-00-00          59 ST      BMT  08/25/2018  16:00:00
# ...      ...    ...       ...            ...      ...         ...       ...
# 197620  R469  TRAM2  00-05-01  RIT-ROOSEVELT      RIT  08/31/2018  05:00:00
# 197621  R469  TRAM2  00-05-01  RIT-ROOSEVELT      RIT  08/31/2018  09:00:00
# 197622  R469  TRAM2  00-05-01  RIT-ROOSEVELT      RIT  08/31/2018  13:00:00
# 197623  R469  TRAM2  00-05-01  RIT-ROOSEVELT      RIT  08/31/2018  17:00:00
# 197624  R469  TRAM2  00-05-01  RIT-ROOSEVELT      RIT  08/31/2018  21:00:00
#
#            desc  entries  \
# 0       REGULAR  6736067
# 1       REGULAR  6736087
# 2       REGULAR  6736105
# 3       REGULAR  6736180
# 4       REGULAR  6736349
# ...         ...      ...
# 197620  REGULAR     5554
# 197621  REGULAR     5554
# 197622  REGULAR     5554
# 197623  REGULAR     5554
# 197624  REGULAR     5554
#
#         exits
# 0                                                 2283184
# 1                                                 2283188
# 2                                                 2283229
# 3                                                 2283314
# 4                                                 2283384
# ...                                                   ...
# 197620                                                348
# 197621                                                348
# 197622                                                348
# 197623                                                348
# 197624                                                348
#
# [197625 rows x 10 columns]

# %%
#adding column called num_lines
df['num_lines'] = df.map(lambda x:len(x))
df.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 2
#       1 #adding column called num_lines
# ----> 2 df['num_lines'] = df.map(lambda x:len(x))
#       3 df.head()
#
# File ~\anaco\Lib\site-packages\pandas\core\frame.py:10120, in DataFrame.map(self, func, na_action, **kwargs)
#   10117 def infer(x):
#   10118     return x._map_values(func, na_action=na_action)
# > 10120 return self.apply(infer).__finalize__(self, "map")
#
# File ~\anaco\Lib\site-packages\pandas\core\frame.py:10034, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, **kwargs)
#   10022 from pandas.core.apply import frame_apply
#   10024 op = frame_apply(
#   10025     self,
#   10026     func=func,
#    (...)
#   10032     kwargs=kwargs,
#   10033 )
# > 10034 return op.apply().__finalize__(self, method="apply")
#
# File ~\anaco\Lib\site-packages\pandas\core\apply.py:837, in FrameApply.apply(self)
#     834 elif self.raw:
#     835     return self.apply_raw()
# --> 837 return self.apply_standard()
#
# File ~\anaco\Lib\site-packages\pandas\core\apply.py:965, in FrameApply.apply_standard(self)
#     964 def apply_standard(self):
# --> 965     results, res_index = self.apply_series_generator()
#     967     # wrap results
#     968     return self.wrap_results(results, res_index)
#
# File ~\anaco\Lib\site-packages\pandas\core\apply.py:981, in FrameApply.apply_series_generator(self)
#     978 with option_context("mode.chained_assignment", None):
#     979     for i, v in enumerate(series_gen):
#     980         # ignore SettingWithCopy here in case the user mutates
# --> 981         results[i] = self.func(v, *self.args, **self.kwargs)
#     982         if isinstance(results[i], ABCSeries):
#     983             # If we have a view on v, we need to make a copy because
#     984             #  series_generator will swap out the underlying data
#     985             results[i] = results[i].copy(deep=False)
#
# File ~\anaco\Lib\site-packages\pandas\core\frame.py:10118, in DataFrame.map.<locals>.infer(x)
#   10117 def infer(x):
# > 10118     return x._map_values(func, na_action=na_action)
#
# File ~\anaco\Lib\site-packages\pandas\core\base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File ~\anaco\Lib\site-packages\pandas\core\algorithms.py:1814, in map_array(arr, mapper, na_action, convert)
#    1812 values = arr.astype(object, copy=False)
#    1813 if na_action is None:
# -> 1814     return lib.map_infer(values, mapper, convert=convert)
#    1815 else:
#    1816     return lib.map_infer_mask(
#    1817         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1818     )
#
# File lib.pyx:2926, in pandas._libs.lib.map_infer()
#
# Cell In[27], line 2, in <lambda>(x)
#       1 #adding column called num_lines
# ----> 2 df['num_lines'] = df.map(lambda x:len(x))
#       3 df.head()
#
# TypeError: object of type 'int' has no len()
